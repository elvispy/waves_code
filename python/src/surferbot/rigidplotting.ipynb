# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

from surferbot.rigid import rigidSolver

# %%
# Sample Variables
L_raft = 0.3
L_domain = 1
sigma = 0.072
x_A = 0.02
F_A = 1
n = 21



[phi, eta, zeta, theta] = rigidSolver(1000, 10, 1e-6, 9.81, L_raft, L_domain, 0.072, x_A, F_A, n)

# making dimensional
eta_dim = eta * L_raft
zeta_dim = zeta * L_raft
# Out:
# Total number of points in the domain: 63
# N shape: (63, 63)
# d_dx_left: (Array(22, dtype=int32, weak_type=True),)
# left_raft_boundary: 21
# number of free points: 21
# E1 Phi Shape, First Half: (21, 63)
# E1 Phi Shape: (42, 63)
# A shape: (191, 191)
# b shape: (191, 1)
# Determinant of A: (20.92810821533203-127.74758911132812j)
# Rank of matrix: 190
# Shape of matrix: (191, 191)
# Dependent row indices: [np.int32(41)]
# Matrix has linearly dependent rows or columns.

# %%
# Plotting
x = jnp.arange(-L_domain/2, L_domain/2, 1/p)

print(x.shape)

y = eta_dim
print(y.shape)
plt.xlim(-L_domain/2, L_domain/2)
# plt.plot(x, y , marker = 'o')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Plotting
# ----> 2 x = jnp.arange(-L_domain/2, L_domain/2, 1/p)
#       4 print(x.shape)
#       6 y = eta_dim
#
# NameError: name 'p' is not defined
